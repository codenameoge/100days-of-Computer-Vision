# %% [markdown]
# <a href="https://colab.research.google.com/github/codenameoge/100days-of-Computer-Vision/blob/main/remote_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #%% [markdown]
# # # Remote Sensing Image Segmentation with Partial Cross-Entropy Loss
# #
# # This notebook implements the following:
# # 1. Downloads and preprocesses the **Global Land Cover Mapping (OpenEarthMap)** dataset from Kaggle.
# # 2. Implements a custom **Partial Cross-Entropy Loss** that computes loss only on randomly sampled points from the segmentation mask.
# # 3. Builds a simple U-Net segmentation network.
# # 4. Trains and evaluates the model on the remote sensing dataset.
# # 5. Visualizes segmentation predictions.
# #
# # The code is designed for Google Colab and uses PyTorch for model development.

# %%
# Install necessary packages and set up Kaggle API
# !pip install kaggle
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

import os
import random
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from glob import glob
from tqdm import tqdm
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.11/dist-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.11/dist-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.11/dist-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.11/dist-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)

# %%
 ## Kaggle Setup & Dataset Download
#
# Configure your Kaggle credentials and download the dataset from:
# [Global Land Cover Mapping (OpenEarthMap)](https://www.kaggle.com/datasets/aletbm/global-land-cover-mapping-openearthmap/data)

# Set up Kaggle API (make sure to replace with your credentials)
# !mkdir -p ~/.kaggle
# !echo '{"username":"ogechiezedozie","key":"2bed850e5fe8a7a9e7695ba09633c37e"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download dataset from Kaggle (this may take a few minutes)
# !kaggle datasets download -d aletbm/global-land-cover-mapping-openearthmap --unzip -p /content/OpenEarthMap
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aletbm/global-land-cover-mapping-openearthmap
# License(s): CC-BY-NC-SA-4.0
# Downloading global-land-cover-mapping-openearthmap.zip to /content/OpenEarthMap
# 100% 8.46G/8.47G [03:19<00:00, 91.1MB/s]
# 100% 8.47G/8.47G [03:19<00:00, 45.6MB/s]

# %%
# Define preprocessing parameters
IMG_SIZE = (256, 256)        # Resize images and masks to 256x256
SAMPLE_POINTS = 100          # Number of random points to sample from each mask
BATCH_SIZE = 8
EPOCHS = 10

# %%
# Define dataset base path and split files
DATASET_PATH = "/content/OpenEarthMap"
IMAGE_SPLITS = {"train": "train.txt", "val": "val.txt", "test": "test.txt"}
# Set directories for images and labels
IMAGE_DIR = os.path.join(DATASET_PATH, "images")
MASK_DIR = os.path.join(DATASET_PATH, "label")

# %%
## Loading Filenames for Each Split
#
# The function `load_filenames()` reads the filenames from `train.txt`, `val.txt`, and `test.txt`
# and constructs full paths by including the subfolder names (train, val, test).

def load_filenames():
    """
    Load filenames for each split and build full paths.
    """
    split_files = {split: os.path.join(DATASET_PATH, filename) for split, filename in IMAGE_SPLITS.items()}
    dataset = {"train": [], "val": [], "test": []}

    for split, split_file in split_files.items():
        if not os.path.exists(split_file):
            print(f"Error: {split_file} does not exist!")
            continue

        with open(split_file, 'r') as f:
            filenames = [line.strip() for line in f.readlines()]

        # Include subfolder (train, val, or test) in the full paths
        image_files = [os.path.join(IMAGE_DIR, split, f) for f in filenames]
        mask_files = [os.path.join(MASK_DIR, split, f) for f in filenames]

        # (Optional) Print first few samples for debugging
        for img, mask in zip(image_files[:5], mask_files[:5]):
            print(f"Image: {img}, Mask: {mask}")

        dataset[split] = list(zip(image_files, mask_files))

    return dataset

# %%
 ## Helper Functions for Preprocessing and Visualization
#
# These functions load and preprocess images, sample random point labels from masks,
# and visualize an image-mask pair.

def visualize_sample(image_path, mask_path):
    """Visualize an image and its corresponding mask."""
    if not os.path.exists(image_path) or not os.path.exists(mask_path):
        print(f"Error: File not found -> {image_path} or {mask_path}")
        return

    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if image is None or mask is None:
        print(f"Error: Unable to load {image_path} or {mask_path}")
        return

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("Satellite Image")
    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap='gray')
    plt.title("Segmentation Mask")
    plt.show()


def preprocess_image(image_path, mask_path):
    """Load and preprocess image and mask."""
    if not os.path.exists(image_path) or not os.path.exists(mask_path):
        print(f"Warning: Skipping missing file {image_path} or {mask_path}")
        return None, None

    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if image is None or mask is None:
        print(f"Warning: Unable to load {image_path} or {mask_path}")
        return None, None

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, IMG_SIZE) / 255.0  # Normalize image

    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    return image, mask


def sample_point_labels(mask, num_points=SAMPLE_POINTS):
    """
    Randomly sample num_points from the mask.
    Returns a list of (x, y, label) tuples.
    """
    height, width = mask.shape
    sampled_points = []
    for _ in range(num_points):
        x = random.randint(0, width - 1)
        y = random.randint(0, height - 1)
        label = int(mask[y, x])  # Convert label to int
        sampled_points.append((x, y, label))
    return sampled_points

# %%
 ## Process the Dataset
#
# This function loads filenames for train, val, and test splits and processes each sample:
# - Loads and preprocesses images and masks.
# - Samples random point labels from the mask.
#
# **Note:** Since the test set does not have labels in this dataset, we only process the train and val sets.

def process_dataset():
    dataset_splits = load_filenames()
    processed_data = {"train": [], "val": []}  # Only process train and val sets

    for split in ["train", "val"]:
        files = dataset_splits[split]
        for img_path, mask_path in tqdm(files, total=len(files), desc=f"Processing {split} set"):
            if not os.path.exists(img_path) or not os.path.exists(mask_path):
                print(f"Warning: Missing file {img_path} or {mask_path}")
                continue

            image, mask = preprocess_image(img_path, mask_path)
            if image is None or mask is None:
                print(f"Warning: Skipping corrupted file {img_path} or {mask_path}")
                continue

            point_labels = sample_point_labels(mask)
            processed_data[split].append({
                "image": image,
                "mask": mask,
                "points": point_labels
            })
    return processed_data

# %%
 ## PyTorch Dataset and DataLoader
#
# We define a custom dataset class that returns an image, mask, and sampled point labels for each sample.
# Then, we create DataLoaders for the train and validation sets.

class RemoteSensingDataset(Dataset):
    def __init__(self, dataset_split):
        # Filter out any samples that are None
        self.data = [sample for sample in dataset_split if sample and sample.get("image") is not None and sample.get("mask") is not None]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        # Convert image to tensor with shape (C, H, W)
        image = torch.tensor(sample["image"].transpose(2, 0, 1), dtype=torch.float32)
        mask = torch.tensor(sample["mask"], dtype=torch.long)
        points = sample["points"]
        return image, mask, points

def custom_collate_fn(batch):
    """
    Custom collate function to handle the 'points' field properly.
    It stacks images and masks but leaves the points as a list.
    """
    images, masks, points = zip(*batch)
    images = torch.stack(images, 0)
    masks = torch.stack(masks, 0)
    # points is left as a tuple of lists (one per sample)
    return images, masks, points

# Update the DataLoader creation to use the custom collate function:
def create_dataloaders(processed_data):
    train_dataset = RemoteSensingDataset(processed_data["train"])
    val_dataset = RemoteSensingDataset(processed_data["val"])

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=custom_collate_fn)
    return train_loader, val_loader

# Now, when you iterate over train_loader, your sampled_points should remain a list of tuples.

# %%
 ## Partial Cross-Entropy Loss
#
# This custom loss function computes cross-entropy loss only at the sampled point locations.
# It expects that each sample's `sampled_points` is a list of tuples `(x, y, label)`.

class PartialCrossEntropyLoss(nn.Module):
    def __init__(self):
        super(PartialCrossEntropyLoss, self).__init__()
        self.criterion = nn.CrossEntropyLoss(reduction='none')

    def forward(self, predictions, targets, sampled_points):
        # predictions: [batch_size, num_classes, height, width]
        batch_size = predictions.shape[0]
        loss_list = []  # List to accumulate losses for each sample

        for i in range(batch_size):
            if len(sampled_points[i]) == 0:
                continue  # Skip if no points in this sample

            try:
                # Unpack the list of (x, y, label) tuples into separate lists
                x_coords, y_coords, labels = zip(*sampled_points[i])
            except ValueError as e:
                print(f"Error unpacking sampled points in sample {i}: {e}")
                print(f"Full sampled_points[{i}]: {sampled_points[i]}")
                continue  # Skip this sample if unpacking fails

            # Use lists of coordinates to index the predictions
            pred_values = predictions[i, :, list(y_coords), list(x_coords)]  # shape: [num_points, num_classes]
            target_values = torch.tensor(labels, dtype=torch.long, device=predictions.device)

            # Compute cross entropy loss on the sampled points and take the mean
            sample_loss = self.criterion(pred_values, target_values).mean()
            loss_list.append(sample_loss)

        if loss_list:
            return torch.stack(loss_list).mean()
        else:
            # Return a zero tensor with grad enabled if no loss was computed (this should be rare)
            return torch.tensor(0.0, device=predictions.device, requires_grad=True)

# %%
## U-Net Model for Segmentation
#
# Here, we implement a simple U-Net model for remote sensing segmentation.
# You can adjust the architecture as needed.

class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=6):
        """
        in_channels: number of input image channels (RGB -> 3)
        out_channels: number of segmentation classes (adjust according to your dataset)
        """
        super(UNet, self).__init__()
        # Encoder: Two convolution layers
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU()
        )
        # Decoder: Upsample using convolution layers
        self.decoder = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, out_channels, kernel_size=1)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
## Initialize Model, Optimizer, and Loss Function
#
# We create an instance of the U-Net model, set up the Adam optimizer, and instantiate the custom Partial Cross-Entropy Loss.

model = UNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = PartialCrossEntropyLoss()

# %%
## Training, Evaluation, and Visualization Functions
#
# The following functions handle training, evaluation, and visualization:
#
# - **train_model()**: Trains the model for a specified number of epochs.
# - **evaluate_model()**: Computes the average validation loss.
# - **visualize_predictions()**: Displays original images, ground truth masks, and model predictions.

def train_model(model, train_loader, val_loader, criterion, optimizer, epochs=EPOCHS):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    criterion.to(device)

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        # Debug: Print sampled points for the first batch in each epoch (optional)
        for images, masks, sampled_points in train_loader:
            print("Sampled Points Example:", sampled_points[:3])
            break  # Print once per epoch

        for images, masks, sampled_points in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks, sampled_points)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.4f}")


def evaluate_model(model, val_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    total_loss = 0.0
    with torch.no_grad():
        for images, masks, sampled_points in val_loader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            loss = criterion(outputs, masks, sampled_points)
            total_loss += loss.item()

    avg_val_loss = total_loss / len(val_loader)
    print(f"Validation Loss: {avg_val_loss:.4f}")


def visualize_predictions(model, val_loader, num_samples=3):
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    with torch.no_grad():
        for i, (images, masks, sampled_points) in enumerate(val_loader):
            if i >= num_samples:
                break

            images = images.to(device)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=1).cpu().numpy()
            masks = masks.cpu().numpy()

            # Create subplots: one row per image, three columns (Original, Ground Truth, Prediction)
            fig, axes = plt.subplots(len(images), 3, figsize=(12, 4 * len(images)))
            if len(images) == 1:
                axes = [axes]  # Ensure axes is iterable for one sample

            for j in range(len(images)):
                axes[j][0].imshow(images[j].permute(1, 2, 0).cpu().numpy())
                axes[j][0].set_title("Original Image")
                axes[j][0].axis("off")

                axes[j][1].imshow(masks[j], cmap="gray")
                axes[j][1].set_title("Ground Truth")
                axes[j][1].axis("off")

                axes[j][2].imshow(predictions[j], cmap="gray")
                axes[j][2].set_title("Model Prediction")
                axes[j][2].axis("off")

            plt.tight_layout()
            plt.show()

# %%
 ## Run the Full Pipeline
#
# Finally, we process the dataset, create data loaders, train the model, evaluate its performance on the validation set, and visualize predictions.

if __name__ == "__main__":
    # Load filenames and process dataset
    dataset_splits = load_filenames()
    processed_data = process_dataset()
    print("Dataset processing complete! Ready for training.")
    print(f"Processed Train Samples: {len(processed_data['train'])}")
    print(f"Processed Validation Samples: {len(processed_data['val'])}")

    # Create DataLoaders
    train_loader, val_loader = create_dataloaders(processed_data)
    print(f"Train batches: {len(train_loader)}, Validation batches: {len(val_loader)}")

    # Train the model
    train_model(model, train_loader, val_loader, criterion, optimizer)

    # Evaluate the model on validation set
    evaluate_model(model, val_loader)

    # Visualize predictions on validation samples
    visualize_predictions(model, val_loader)

    # Optionally, save the trained model
    torch.save(model.state_dict(), "unet_model.pth")
    print("Model saved successfully!")
# Out:
# Image: /content/OpenEarthMap/images/train/aachen_1.tif, Mask: /content/OpenEarthMap/label/train/aachen_1.tif
# Image: /content/OpenEarthMap/images/train/aachen_10.tif, Mask: /content/OpenEarthMap/label/train/aachen_10.tif
# Image: /content/OpenEarthMap/images/train/aachen_12.tif, Mask: /content/OpenEarthMap/label/train/aachen_12.tif
# Image: /content/OpenEarthMap/images/train/aachen_13.tif, Mask: /content/OpenEarthMap/label/train/aachen_13.tif
# Image: /content/OpenEarthMap/images/train/aachen_14.tif, Mask: /content/OpenEarthMap/label/train/aachen_14.tif
# Image: /content/OpenEarthMap/images/val/aachen_11.tif, Mask: /content/OpenEarthMap/label/val/aachen_11.tif
# Image: /content/OpenEarthMap/images/val/aachen_39.tif, Mask: /content/OpenEarthMap/label/val/aachen_39.tif
# Image: /content/OpenEarthMap/images/val/aachen_42.tif, Mask: /content/OpenEarthMap/label/val/aachen_42.tif
# Image: /content/OpenEarthMap/images/val/aachen_5.tif, Mask: /content/OpenEarthMap/label/val/aachen_5.tif
# Image: /content/OpenEarthMap/images/val/aachen_53.tif, Mask: /content/OpenEarthMap/label/val/aachen_53.tif
# Image: /content/OpenEarthMap/images/test/aachen_17.tif, Mask: /content/OpenEarthMap/label/test/aachen_17.tif
# Image: /content/OpenEarthMap/images/test/aachen_20.tif, Mask: /content/OpenEarthMap/label/test/aachen_20.tif
# Image: /content/OpenEarthMap/images/test/aachen_23.tif, Mask: /content/OpenEarthMap/label/test/aachen_23.tif
# Image: /content/OpenEarthMap/images/test/aachen_25.tif, Mask: /content/OpenEarthMap/label/test/aachen_25.tif
# Image: /content/OpenEarthMap/images/test/aachen_3.tif, Mask: /content/OpenEarthMap/label/test/aachen_3.tif
# Image: /content/OpenEarthMap/images/train/aachen_1.tif, Mask: /content/OpenEarthMap/label/train/aachen_1.tif
# Image: /content/OpenEarthMap/images/train/aachen_10.tif, Mask: /content/OpenEarthMap/label/train/aachen_10.tif
# Image: /content/OpenEarthMap/images/train/aachen_12.tif, Mask: /content/OpenEarthMap/label/train/aachen_12.tif
# Image: /content/OpenEarthMap/images/train/aachen_13.tif, Mask: /content/OpenEarthMap/label/train/aachen_13.tif
# Image: /content/OpenEarthMap/images/train/aachen_14.tif, Mask: /content/OpenEarthMap/label/train/aachen_14.tif
# Image: /content/OpenEarthMap/images/val/aachen_11.tif, Mask: /content/OpenEarthMap/label/val/aachen_11.tif
# Image: /content/OpenEarthMap/images/val/aachen_39.tif, Mask: /content/OpenEarthMap/label/val/aachen_39.tif
# Image: /content/OpenEarthMap/images/val/aachen_42.tif, Mask: /content/OpenEarthMap/label/val/aachen_42.tif
# Image: /content/OpenEarthMap/images/val/aachen_5.tif, Mask: /content/OpenEarthMap/label/val/aachen_5.tif
# Image: /content/OpenEarthMap/images/val/aachen_53.tif, Mask: /content/OpenEarthMap/label/val/aachen_53.tif
# Image: /content/OpenEarthMap/images/test/aachen_17.tif, Mask: /content/OpenEarthMap/label/test/aachen_17.tif
# Image: /content/OpenEarthMap/images/test/aachen_20.tif, Mask: /content/OpenEarthMap/label/test/aachen_20.tif
# Image: /content/OpenEarthMap/images/test/aachen_23.tif, Mask: /content/OpenEarthMap/label/test/aachen_23.tif
# Image: /content/OpenEarthMap/images/test/aachen_25.tif, Mask: /content/OpenEarthMap/label/test/aachen_25.tif
# Image: /content/OpenEarthMap/images/test/aachen_3.tif, Mask: /content/OpenEarthMap/label/test/aachen_3.tif
# Processing train set:   5%|▌         | 158/3000 [00:04<00:22, 125.50it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_10.tif or /content/OpenEarthMap/label/train/adelaide_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_12.tif or /content/OpenEarthMap/label/train/adelaide_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_13.tif or /content/OpenEarthMap/label/train/adelaide_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_15.tif or /content/OpenEarthMap/label/train/adelaide_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_16.tif or /content/OpenEarthMap/label/train/adelaide_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_17.tif or /content/OpenEarthMap/label/train/adelaide_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_2.tif or /content/OpenEarthMap/label/train/adelaide_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_20.tif or /content/OpenEarthMap/label/train/adelaide_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_21.tif or /content/OpenEarthMap/label/train/adelaide_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_22.tif or /content/OpenEarthMap/label/train/adelaide_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_23.tif or /content/OpenEarthMap/label/train/adelaide_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_26.tif or /content/OpenEarthMap/label/train/adelaide_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_27.tif or /content/OpenEarthMap/label/train/adelaide_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_28.tif or /content/OpenEarthMap/label/train/adelaide_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_29.tif or /content/OpenEarthMap/label/train/adelaide_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_3.tif or /content/OpenEarthMap/label/train/adelaide_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_31.tif or /content/OpenEarthMap/label/train/adelaide_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_32.tif or /content/OpenEarthMap/label/train/adelaide_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_33.tif or /content/OpenEarthMap/label/train/adelaide_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_34.tif or /content/OpenEarthMap/label/train/adelaide_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_37.tif or /content/OpenEarthMap/label/train/adelaide_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_38.tif or /content/OpenEarthMap/label/train/adelaide_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_39.tif or /content/OpenEarthMap/label/train/adelaide_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_4.tif or /content/OpenEarthMap/label/train/adelaide_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_44.tif or /content/OpenEarthMap/label/train/adelaide_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_47.tif or /content/OpenEarthMap/label/train/adelaide_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_53.tif or /content/OpenEarthMap/label/train/adelaide_53.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_54.tif or /content/OpenEarthMap/label/train/adelaide_54.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_55.tif or /content/OpenEarthMap/label/train/adelaide_55.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_56.tif or /content/OpenEarthMap/label/train/adelaide_56.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_57.tif or /content/OpenEarthMap/label/train/adelaide_57.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_58.tif or /content/OpenEarthMap/label/train/adelaide_58.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_60.tif or /content/OpenEarthMap/label/train/adelaide_60.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_62.tif or /content/OpenEarthMap/label/train/adelaide_62.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_63.tif or /content/OpenEarthMap/label/train/adelaide_63.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_64.tif or /content/OpenEarthMap/label/train/adelaide_64.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_65.tif or /content/OpenEarthMap/label/train/adelaide_65.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_66.tif or /content/OpenEarthMap/label/train/adelaide_66.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_67.tif or /content/OpenEarthMap/label/train/adelaide_67.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_69.tif or /content/OpenEarthMap/label/train/adelaide_69.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_70.tif or /content/OpenEarthMap/label/train/adelaide_70.tif
# Warning: Missing file /content/OpenEarthMap/images/train/adelaide_9.tif or /content/OpenEarthMap/label/train/adelaide_9.tif
# Processing train set:  31%|███       | 922/3000 [00:25<00:08, 257.53it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_10.tif or /content/OpenEarthMap/label/train/el_rodeo_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_12.tif or /content/OpenEarthMap/label/train/el_rodeo_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_13.tif or /content/OpenEarthMap/label/train/el_rodeo_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_14.tif or /content/OpenEarthMap/label/train/el_rodeo_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_16.tif or /content/OpenEarthMap/label/train/el_rodeo_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_17.tif or /content/OpenEarthMap/label/train/el_rodeo_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_19.tif or /content/OpenEarthMap/label/train/el_rodeo_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_2.tif or /content/OpenEarthMap/label/train/el_rodeo_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_22.tif or /content/OpenEarthMap/label/train/el_rodeo_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_3.tif or /content/OpenEarthMap/label/train/el_rodeo_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_4.tif or /content/OpenEarthMap/label/train/el_rodeo_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_5.tif or /content/OpenEarthMap/label/train/el_rodeo_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/el_rodeo_9.tif or /content/OpenEarthMap/label/train/el_rodeo_9.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_10.tif or /content/OpenEarthMap/label/train/gorakhpur_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_11.tif or /content/OpenEarthMap/label/train/gorakhpur_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_14.tif or /content/OpenEarthMap/label/train/gorakhpur_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_15.tif or /content/OpenEarthMap/label/train/gorakhpur_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_16.tif or /content/OpenEarthMap/label/train/gorakhpur_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_17.tif or /content/OpenEarthMap/label/train/gorakhpur_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_18.tif or /content/OpenEarthMap/label/train/gorakhpur_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_19.tif or /content/OpenEarthMap/label/train/gorakhpur_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_25.tif or /content/OpenEarthMap/label/train/gorakhpur_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_26.tif or /content/OpenEarthMap/label/train/gorakhpur_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_27.tif or /content/OpenEarthMap/label/train/gorakhpur_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_29.tif or /content/OpenEarthMap/label/train/gorakhpur_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_3.tif or /content/OpenEarthMap/label/train/gorakhpur_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_30.tif or /content/OpenEarthMap/label/train/gorakhpur_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_31.tif or /content/OpenEarthMap/label/train/gorakhpur_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_32.tif or /content/OpenEarthMap/label/train/gorakhpur_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_34.tif or /content/OpenEarthMap/label/train/gorakhpur_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_35.tif or /content/OpenEarthMap/label/train/gorakhpur_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_36.tif or /content/OpenEarthMap/label/train/gorakhpur_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_37.tif or /content/OpenEarthMap/label/train/gorakhpur_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_39.tif or /content/OpenEarthMap/label/train/gorakhpur_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_4.tif or /content/OpenEarthMap/label/train/gorakhpur_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_40.tif or /content/OpenEarthMap/label/train/gorakhpur_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_43.tif or /content/OpenEarthMap/label/train/gorakhpur_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_44.tif or /content/OpenEarthMap/label/train/gorakhpur_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_47.tif or /content/OpenEarthMap/label/train/gorakhpur_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_49.tif or /content/OpenEarthMap/label/train/gorakhpur_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_5.tif or /content/OpenEarthMap/label/train/gorakhpur_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_50.tif or /content/OpenEarthMap/label/train/gorakhpur_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_51.tif or /content/OpenEarthMap/label/train/gorakhpur_51.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_52.tif or /content/OpenEarthMap/label/train/gorakhpur_52.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_55.tif or /content/OpenEarthMap/label/train/gorakhpur_55.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_56.tif or /content/OpenEarthMap/label/train/gorakhpur_56.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_57.tif or /content/OpenEarthMap/label/train/gorakhpur_57.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_58.tif or /content/OpenEarthMap/label/train/gorakhpur_58.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_59.tif or /content/OpenEarthMap/label/train/gorakhpur_59.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_63.tif or /content/OpenEarthMap/label/train/gorakhpur_63.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_65.tif or /content/OpenEarthMap/label/train/gorakhpur_65.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_67.tif or /content/OpenEarthMap/label/train/gorakhpur_67.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_68.tif or /content/OpenEarthMap/label/train/gorakhpur_68.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_70.tif or /content/OpenEarthMap/label/train/gorakhpur_70.tif
# Warning: Missing file /content/OpenEarthMap/images/train/gorakhpur_9.tif or /content/OpenEarthMap/label/train/gorakhpur_9.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_1.tif or /content/OpenEarthMap/label/train/houston_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_10.tif or /content/OpenEarthMap/label/train/houston_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_12.tif or /content/OpenEarthMap/label/train/houston_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_14.tif or /content/OpenEarthMap/label/train/houston_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_17.tif or /content/OpenEarthMap/label/train/houston_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_19.tif or /content/OpenEarthMap/label/train/houston_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_20.tif or /content/OpenEarthMap/label/train/houston_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_21.tif or /content/OpenEarthMap/label/train/houston_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_22.tif or /content/OpenEarthMap/label/train/houston_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_23.tif or /content/OpenEarthMap/label/train/houston_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_24.tif or /content/OpenEarthMap/label/train/houston_24.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_26.tif or /content/OpenEarthMap/label/train/houston_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_28.tif or /content/OpenEarthMap/label/train/houston_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_29.tif or /content/OpenEarthMap/label/train/houston_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_3.tif or /content/OpenEarthMap/label/train/houston_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_31.tif or /content/OpenEarthMap/label/train/houston_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_32.tif or /content/OpenEarthMap/label/train/houston_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_33.tif or /content/OpenEarthMap/label/train/houston_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_34.tif or /content/OpenEarthMap/label/train/houston_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_35.tif or /content/OpenEarthMap/label/train/houston_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_39.tif or /content/OpenEarthMap/label/train/houston_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_4.tif or /content/OpenEarthMap/label/train/houston_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_41.tif or /content/OpenEarthMap/label/train/houston_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_43.tif or /content/OpenEarthMap/label/train/houston_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_44.tif or /content/OpenEarthMap/label/train/houston_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_45.tif or /content/OpenEarthMap/label/train/houston_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_47.tif or /content/OpenEarthMap/label/train/houston_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_49.tif or /content/OpenEarthMap/label/train/houston_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_50.tif or /content/OpenEarthMap/label/train/houston_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/houston_9.tif or /content/OpenEarthMap/label/train/houston_9.tif
# Processing train set:  34%|███▍      | 1024/3000 [00:26<00:11, 172.27it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_1.tif or /content/OpenEarthMap/label/train/jeremie_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_10.tif or /content/OpenEarthMap/label/train/jeremie_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_11.tif or /content/OpenEarthMap/label/train/jeremie_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_12.tif or /content/OpenEarthMap/label/train/jeremie_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_13.tif or /content/OpenEarthMap/label/train/jeremie_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_14.tif or /content/OpenEarthMap/label/train/jeremie_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_15.tif or /content/OpenEarthMap/label/train/jeremie_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_16.tif or /content/OpenEarthMap/label/train/jeremie_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_17.tif or /content/OpenEarthMap/label/train/jeremie_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_18.tif or /content/OpenEarthMap/label/train/jeremie_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_2.tif or /content/OpenEarthMap/label/train/jeremie_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_20.tif or /content/OpenEarthMap/label/train/jeremie_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_21.tif or /content/OpenEarthMap/label/train/jeremie_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_22.tif or /content/OpenEarthMap/label/train/jeremie_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_23.tif or /content/OpenEarthMap/label/train/jeremie_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_25.tif or /content/OpenEarthMap/label/train/jeremie_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_26.tif or /content/OpenEarthMap/label/train/jeremie_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_28.tif or /content/OpenEarthMap/label/train/jeremie_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_29.tif or /content/OpenEarthMap/label/train/jeremie_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_30.tif or /content/OpenEarthMap/label/train/jeremie_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_31.tif or /content/OpenEarthMap/label/train/jeremie_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_32.tif or /content/OpenEarthMap/label/train/jeremie_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_34.tif or /content/OpenEarthMap/label/train/jeremie_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_39.tif or /content/OpenEarthMap/label/train/jeremie_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_4.tif or /content/OpenEarthMap/label/train/jeremie_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_41.tif or /content/OpenEarthMap/label/train/jeremie_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_42.tif or /content/OpenEarthMap/label/train/jeremie_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_44.tif or /content/OpenEarthMap/label/train/jeremie_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_46.tif or /content/OpenEarthMap/label/train/jeremie_46.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_49.tif or /content/OpenEarthMap/label/train/jeremie_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_51.tif or /content/OpenEarthMap/label/train/jeremie_51.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_54.tif or /content/OpenEarthMap/label/train/jeremie_54.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_57.tif or /content/OpenEarthMap/label/train/jeremie_57.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_61.tif or /content/OpenEarthMap/label/train/jeremie_61.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_64.tif or /content/OpenEarthMap/label/train/jeremie_64.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_65.tif or /content/OpenEarthMap/label/train/jeremie_65.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_66.tif or /content/OpenEarthMap/label/train/jeremie_66.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_67.tif or /content/OpenEarthMap/label/train/jeremie_67.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_68.tif or /content/OpenEarthMap/label/train/jeremie_68.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_69.tif or /content/OpenEarthMap/label/train/jeremie_69.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_7.tif or /content/OpenEarthMap/label/train/jeremie_7.tif
# Warning: Missing file /content/OpenEarthMap/images/train/jeremie_8.tif or /content/OpenEarthMap/label/train/jeremie_8.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_11.tif or /content/OpenEarthMap/label/train/joplin_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_12.tif or /content/OpenEarthMap/label/train/joplin_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_17.tif or /content/OpenEarthMap/label/train/joplin_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_19.tif or /content/OpenEarthMap/label/train/joplin_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_2.tif or /content/OpenEarthMap/label/train/joplin_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_22.tif or /content/OpenEarthMap/label/train/joplin_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_23.tif or /content/OpenEarthMap/label/train/joplin_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_25.tif or /content/OpenEarthMap/label/train/joplin_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_28.tif or /content/OpenEarthMap/label/train/joplin_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_29.tif or /content/OpenEarthMap/label/train/joplin_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_3.tif or /content/OpenEarthMap/label/train/joplin_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_31.tif or /content/OpenEarthMap/label/train/joplin_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_32.tif or /content/OpenEarthMap/label/train/joplin_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_33.tif or /content/OpenEarthMap/label/train/joplin_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_34.tif or /content/OpenEarthMap/label/train/joplin_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_35.tif or /content/OpenEarthMap/label/train/joplin_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_36.tif or /content/OpenEarthMap/label/train/joplin_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_37.tif or /content/OpenEarthMap/label/train/joplin_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_38.tif or /content/OpenEarthMap/label/train/joplin_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_4.tif or /content/OpenEarthMap/label/train/joplin_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_40.tif or /content/OpenEarthMap/label/train/joplin_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_41.tif or /content/OpenEarthMap/label/train/joplin_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_42.tif or /content/OpenEarthMap/label/train/joplin_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_43.tif or /content/OpenEarthMap/label/train/joplin_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_44.tif or /content/OpenEarthMap/label/train/joplin_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_47.tif or /content/OpenEarthMap/label/train/joplin_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_48.tif or /content/OpenEarthMap/label/train/joplin_48.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_6.tif or /content/OpenEarthMap/label/train/joplin_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_8.tif or /content/OpenEarthMap/label/train/joplin_8.tif
# Warning: Missing file /content/OpenEarthMap/images/train/joplin_9.tif or /content/OpenEarthMap/label/train/joplin_9.tif
# Processing train set:  43%|████▎     | 1282/3000 [00:31<00:12, 142.61it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_1.tif or /content/OpenEarthMap/label/train/labuhan_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_10.tif or /content/OpenEarthMap/label/train/labuhan_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_12.tif or /content/OpenEarthMap/label/train/labuhan_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_13.tif or /content/OpenEarthMap/label/train/labuhan_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_15.tif or /content/OpenEarthMap/label/train/labuhan_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_16.tif or /content/OpenEarthMap/label/train/labuhan_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_17.tif or /content/OpenEarthMap/label/train/labuhan_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_18.tif or /content/OpenEarthMap/label/train/labuhan_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_2.tif or /content/OpenEarthMap/label/train/labuhan_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_20.tif or /content/OpenEarthMap/label/train/labuhan_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_22.tif or /content/OpenEarthMap/label/train/labuhan_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_24.tif or /content/OpenEarthMap/label/train/labuhan_24.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_25.tif or /content/OpenEarthMap/label/train/labuhan_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_26.tif or /content/OpenEarthMap/label/train/labuhan_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_3.tif or /content/OpenEarthMap/label/train/labuhan_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_30.tif or /content/OpenEarthMap/label/train/labuhan_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_33.tif or /content/OpenEarthMap/label/train/labuhan_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_34.tif or /content/OpenEarthMap/label/train/labuhan_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_35.tif or /content/OpenEarthMap/label/train/labuhan_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_36.tif or /content/OpenEarthMap/label/train/labuhan_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_38.tif or /content/OpenEarthMap/label/train/labuhan_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_4.tif or /content/OpenEarthMap/label/train/labuhan_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_40.tif or /content/OpenEarthMap/label/train/labuhan_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_45.tif or /content/OpenEarthMap/label/train/labuhan_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_49.tif or /content/OpenEarthMap/label/train/labuhan_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_5.tif or /content/OpenEarthMap/label/train/labuhan_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_52.tif or /content/OpenEarthMap/label/train/labuhan_52.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_53.tif or /content/OpenEarthMap/label/train/labuhan_53.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_55.tif or /content/OpenEarthMap/label/train/labuhan_55.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_56.tif or /content/OpenEarthMap/label/train/labuhan_56.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_59.tif or /content/OpenEarthMap/label/train/labuhan_59.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_6.tif or /content/OpenEarthMap/label/train/labuhan_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_60.tif or /content/OpenEarthMap/label/train/labuhan_60.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_61.tif or /content/OpenEarthMap/label/train/labuhan_61.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_62.tif or /content/OpenEarthMap/label/train/labuhan_62.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_63.tif or /content/OpenEarthMap/label/train/labuhan_63.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_65.tif or /content/OpenEarthMap/label/train/labuhan_65.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_67.tif or /content/OpenEarthMap/label/train/labuhan_67.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_68.tif or /content/OpenEarthMap/label/train/labuhan_68.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_7.tif or /content/OpenEarthMap/label/train/labuhan_7.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_70.tif or /content/OpenEarthMap/label/train/labuhan_70.tif
# Warning: Missing file /content/OpenEarthMap/images/train/labuhan_9.tif or /content/OpenEarthMap/label/train/labuhan_9.tif
# Processing train set:  46%|████▌     | 1385/3000 [00:32<00:10, 158.84it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_1.tif or /content/OpenEarthMap/label/train/leilane_estates_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_11.tif or /content/OpenEarthMap/label/train/leilane_estates_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_12.tif or /content/OpenEarthMap/label/train/leilane_estates_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_13.tif or /content/OpenEarthMap/label/train/leilane_estates_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_14.tif or /content/OpenEarthMap/label/train/leilane_estates_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_15.tif or /content/OpenEarthMap/label/train/leilane_estates_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_17.tif or /content/OpenEarthMap/label/train/leilane_estates_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_21.tif or /content/OpenEarthMap/label/train/leilane_estates_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_22.tif or /content/OpenEarthMap/label/train/leilane_estates_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_23.tif or /content/OpenEarthMap/label/train/leilane_estates_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_25.tif or /content/OpenEarthMap/label/train/leilane_estates_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_26.tif or /content/OpenEarthMap/label/train/leilane_estates_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_27.tif or /content/OpenEarthMap/label/train/leilane_estates_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_28.tif or /content/OpenEarthMap/label/train/leilane_estates_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_3.tif or /content/OpenEarthMap/label/train/leilane_estates_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_31.tif or /content/OpenEarthMap/label/train/leilane_estates_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_32.tif or /content/OpenEarthMap/label/train/leilane_estates_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_38.tif or /content/OpenEarthMap/label/train/leilane_estates_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_4.tif or /content/OpenEarthMap/label/train/leilane_estates_4.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_43.tif or /content/OpenEarthMap/label/train/leilane_estates_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_44.tif or /content/OpenEarthMap/label/train/leilane_estates_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_45.tif or /content/OpenEarthMap/label/train/leilane_estates_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_46.tif or /content/OpenEarthMap/label/train/leilane_estates_46.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_47.tif or /content/OpenEarthMap/label/train/leilane_estates_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_48.tif or /content/OpenEarthMap/label/train/leilane_estates_48.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_49.tif or /content/OpenEarthMap/label/train/leilane_estates_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_5.tif or /content/OpenEarthMap/label/train/leilane_estates_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_6.tif or /content/OpenEarthMap/label/train/leilane_estates_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_8.tif or /content/OpenEarthMap/label/train/leilane_estates_8.tif
# Warning: Missing file /content/OpenEarthMap/images/train/leilane_estates_9.tif or /content/OpenEarthMap/label/train/leilane_estates_9.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_1.tif or /content/OpenEarthMap/label/train/les_cayes_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_10.tif or /content/OpenEarthMap/label/train/les_cayes_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_11.tif or /content/OpenEarthMap/label/train/les_cayes_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_13.tif or /content/OpenEarthMap/label/train/les_cayes_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_14.tif or /content/OpenEarthMap/label/train/les_cayes_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_15.tif or /content/OpenEarthMap/label/train/les_cayes_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_16.tif or /content/OpenEarthMap/label/train/les_cayes_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_17.tif or /content/OpenEarthMap/label/train/les_cayes_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_18.tif or /content/OpenEarthMap/label/train/les_cayes_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_2.tif or /content/OpenEarthMap/label/train/les_cayes_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_22.tif or /content/OpenEarthMap/label/train/les_cayes_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_25.tif or /content/OpenEarthMap/label/train/les_cayes_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_29.tif or /content/OpenEarthMap/label/train/les_cayes_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_31.tif or /content/OpenEarthMap/label/train/les_cayes_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_33.tif or /content/OpenEarthMap/label/train/les_cayes_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_36.tif or /content/OpenEarthMap/label/train/les_cayes_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_37.tif or /content/OpenEarthMap/label/train/les_cayes_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_40.tif or /content/OpenEarthMap/label/train/les_cayes_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_42.tif or /content/OpenEarthMap/label/train/les_cayes_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_43.tif or /content/OpenEarthMap/label/train/les_cayes_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_45.tif or /content/OpenEarthMap/label/train/les_cayes_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_47.tif or /content/OpenEarthMap/label/train/les_cayes_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_48.tif or /content/OpenEarthMap/label/train/les_cayes_48.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_49.tif or /content/OpenEarthMap/label/train/les_cayes_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_5.tif or /content/OpenEarthMap/label/train/les_cayes_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_50.tif or /content/OpenEarthMap/label/train/les_cayes_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_51.tif or /content/OpenEarthMap/label/train/les_cayes_51.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_55.tif or /content/OpenEarthMap/label/train/les_cayes_55.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_56.tif or /content/OpenEarthMap/label/train/les_cayes_56.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_57.tif or /content/OpenEarthMap/label/train/les_cayes_57.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_58.tif or /content/OpenEarthMap/label/train/les_cayes_58.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_6.tif or /content/OpenEarthMap/label/train/les_cayes_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_61.tif or /content/OpenEarthMap/label/train/les_cayes_61.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_64.tif or /content/OpenEarthMap/label/train/les_cayes_64.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_65.tif or /content/OpenEarthMap/label/train/les_cayes_65.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_66.tif or /content/OpenEarthMap/label/train/les_cayes_66.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_68.tif or /content/OpenEarthMap/label/train/les_cayes_68.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_69.tif or /content/OpenEarthMap/label/train/les_cayes_69.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_7.tif or /content/OpenEarthMap/label/train/les_cayes_7.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_70.tif or /content/OpenEarthMap/label/train/les_cayes_70.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_8.tif or /content/OpenEarthMap/label/train/les_cayes_8.tif
# Warning: Missing file /content/OpenEarthMap/images/train/les_cayes_9.tif or /content/OpenEarthMap/label/train/les_cayes_9.tif
# Processing train set:  48%|████▊     | 1445/3000 [00:33<00:14, 110.14it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_1.tif or /content/OpenEarthMap/label/train/little_rock_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_10.tif or /content/OpenEarthMap/label/train/little_rock_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_11.tif or /content/OpenEarthMap/label/train/little_rock_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_14.tif or /content/OpenEarthMap/label/train/little_rock_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_15.tif or /content/OpenEarthMap/label/train/little_rock_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_17.tif or /content/OpenEarthMap/label/train/little_rock_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_18.tif or /content/OpenEarthMap/label/train/little_rock_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_19.tif or /content/OpenEarthMap/label/train/little_rock_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_22.tif or /content/OpenEarthMap/label/train/little_rock_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_25.tif or /content/OpenEarthMap/label/train/little_rock_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_26.tif or /content/OpenEarthMap/label/train/little_rock_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_28.tif or /content/OpenEarthMap/label/train/little_rock_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_29.tif or /content/OpenEarthMap/label/train/little_rock_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_3.tif or /content/OpenEarthMap/label/train/little_rock_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_30.tif or /content/OpenEarthMap/label/train/little_rock_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_32.tif or /content/OpenEarthMap/label/train/little_rock_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_34.tif or /content/OpenEarthMap/label/train/little_rock_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_35.tif or /content/OpenEarthMap/label/train/little_rock_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_37.tif or /content/OpenEarthMap/label/train/little_rock_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_38.tif or /content/OpenEarthMap/label/train/little_rock_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_40.tif or /content/OpenEarthMap/label/train/little_rock_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_41.tif or /content/OpenEarthMap/label/train/little_rock_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_42.tif or /content/OpenEarthMap/label/train/little_rock_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_45.tif or /content/OpenEarthMap/label/train/little_rock_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_47.tif or /content/OpenEarthMap/label/train/little_rock_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_48.tif or /content/OpenEarthMap/label/train/little_rock_48.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_49.tif or /content/OpenEarthMap/label/train/little_rock_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_5.tif or /content/OpenEarthMap/label/train/little_rock_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_50.tif or /content/OpenEarthMap/label/train/little_rock_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/little_rock_7.tif or /content/OpenEarthMap/label/train/little_rock_7.tif
# Processing train set:  56%|█████▌    | 1682/3000 [00:39<00:10, 131.47it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/mexico_city_10.tif or /content/OpenEarthMap/label/train/mexico_city_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/mexico_city_11.tif or /content/OpenEarthMap/label/train/mexico_city_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/mexico_city_14.tif or /content/OpenEarthMap/label/train/mexico_city_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/mexico_city_16.tif or /content/OpenEarthMap/label/train/mexico_city_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/mexico_city_17.tif or /content/OpenEarthMap/label/train/mexico_city_17.tif
# ...
# Warning: Missing file /content/OpenEarthMap/images/train/saint_louis_du_sud_9.tif or /content/OpenEarthMap/label/train/saint_louis_du_sud_9.tif
# Processing train set:  76%|███████▌  | 2271/3000 [00:48<00:07, 95.82it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_10.tif or /content/OpenEarthMap/label/train/santa_rosa_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_11.tif or /content/OpenEarthMap/label/train/santa_rosa_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_14.tif or /content/OpenEarthMap/label/train/santa_rosa_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_15.tif or /content/OpenEarthMap/label/train/santa_rosa_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_17.tif or /content/OpenEarthMap/label/train/santa_rosa_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_19.tif or /content/OpenEarthMap/label/train/santa_rosa_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_2.tif or /content/OpenEarthMap/label/train/santa_rosa_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_21.tif or /content/OpenEarthMap/label/train/santa_rosa_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_23.tif or /content/OpenEarthMap/label/train/santa_rosa_23.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_24.tif or /content/OpenEarthMap/label/train/santa_rosa_24.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_27.tif or /content/OpenEarthMap/label/train/santa_rosa_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_30.tif or /content/OpenEarthMap/label/train/santa_rosa_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_32.tif or /content/OpenEarthMap/label/train/santa_rosa_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_33.tif or /content/OpenEarthMap/label/train/santa_rosa_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_34.tif or /content/OpenEarthMap/label/train/santa_rosa_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_35.tif or /content/OpenEarthMap/label/train/santa_rosa_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_36.tif or /content/OpenEarthMap/label/train/santa_rosa_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_37.tif or /content/OpenEarthMap/label/train/santa_rosa_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_38.tif or /content/OpenEarthMap/label/train/santa_rosa_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_39.tif or /content/OpenEarthMap/label/train/santa_rosa_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_40.tif or /content/OpenEarthMap/label/train/santa_rosa_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_41.tif or /content/OpenEarthMap/label/train/santa_rosa_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_42.tif or /content/OpenEarthMap/label/train/santa_rosa_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_43.tif or /content/OpenEarthMap/label/train/santa_rosa_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_45.tif or /content/OpenEarthMap/label/train/santa_rosa_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_47.tif or /content/OpenEarthMap/label/train/santa_rosa_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_49.tif or /content/OpenEarthMap/label/train/santa_rosa_49.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_50.tif or /content/OpenEarthMap/label/train/santa_rosa_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_6.tif or /content/OpenEarthMap/label/train/santa_rosa_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/santa_rosa_8.tif or /content/OpenEarthMap/label/train/santa_rosa_8.tif
# Processing train set:  84%|████████▍ | 2514/3000 [00:55<00:04, 111.77it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_1.tif or /content/OpenEarthMap/label/train/thousand_oaks_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_10.tif or /content/OpenEarthMap/label/train/thousand_oaks_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_12.tif or /content/OpenEarthMap/label/train/thousand_oaks_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_14.tif or /content/OpenEarthMap/label/train/thousand_oaks_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_15.tif or /content/OpenEarthMap/label/train/thousand_oaks_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_17.tif or /content/OpenEarthMap/label/train/thousand_oaks_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_18.tif or /content/OpenEarthMap/label/train/thousand_oaks_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_19.tif or /content/OpenEarthMap/label/train/thousand_oaks_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_2.tif or /content/OpenEarthMap/label/train/thousand_oaks_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_20.tif or /content/OpenEarthMap/label/train/thousand_oaks_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_22.tif or /content/OpenEarthMap/label/train/thousand_oaks_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_26.tif or /content/OpenEarthMap/label/train/thousand_oaks_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_27.tif or /content/OpenEarthMap/label/train/thousand_oaks_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_3.tif or /content/OpenEarthMap/label/train/thousand_oaks_3.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_30.tif or /content/OpenEarthMap/label/train/thousand_oaks_30.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_32.tif or /content/OpenEarthMap/label/train/thousand_oaks_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_33.tif or /content/OpenEarthMap/label/train/thousand_oaks_33.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_34.tif or /content/OpenEarthMap/label/train/thousand_oaks_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_36.tif or /content/OpenEarthMap/label/train/thousand_oaks_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_38.tif or /content/OpenEarthMap/label/train/thousand_oaks_38.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_39.tif or /content/OpenEarthMap/label/train/thousand_oaks_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_40.tif or /content/OpenEarthMap/label/train/thousand_oaks_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_42.tif or /content/OpenEarthMap/label/train/thousand_oaks_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_43.tif or /content/OpenEarthMap/label/train/thousand_oaks_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_44.tif or /content/OpenEarthMap/label/train/thousand_oaks_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_45.tif or /content/OpenEarthMap/label/train/thousand_oaks_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_47.tif or /content/OpenEarthMap/label/train/thousand_oaks_47.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_5.tif or /content/OpenEarthMap/label/train/thousand_oaks_5.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_50.tif or /content/OpenEarthMap/label/train/thousand_oaks_50.tif
# Warning: Missing file /content/OpenEarthMap/images/train/thousand_oaks_7.tif or /content/OpenEarthMap/label/train/thousand_oaks_7.tif
# Processing train set:  89%|████████▊ | 2658/3000 [00:57<00:02, 164.27it/s]
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_1.tif or /content/OpenEarthMap/label/train/tulsa_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_10.tif or /content/OpenEarthMap/label/train/tulsa_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_11.tif or /content/OpenEarthMap/label/train/tulsa_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_13.tif or /content/OpenEarthMap/label/train/tulsa_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_14.tif or /content/OpenEarthMap/label/train/tulsa_14.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_15.tif or /content/OpenEarthMap/label/train/tulsa_15.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_16.tif or /content/OpenEarthMap/label/train/tulsa_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_17.tif or /content/OpenEarthMap/label/train/tulsa_17.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_18.tif or /content/OpenEarthMap/label/train/tulsa_18.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_19.tif or /content/OpenEarthMap/label/train/tulsa_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_2.tif or /content/OpenEarthMap/label/train/tulsa_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_20.tif or /content/OpenEarthMap/label/train/tulsa_20.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_21.tif or /content/OpenEarthMap/label/train/tulsa_21.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_22.tif or /content/OpenEarthMap/label/train/tulsa_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_24.tif or /content/OpenEarthMap/label/train/tulsa_24.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_25.tif or /content/OpenEarthMap/label/train/tulsa_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_26.tif or /content/OpenEarthMap/label/train/tulsa_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_27.tif or /content/OpenEarthMap/label/train/tulsa_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_31.tif or /content/OpenEarthMap/label/train/tulsa_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_32.tif or /content/OpenEarthMap/label/train/tulsa_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_34.tif or /content/OpenEarthMap/label/train/tulsa_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_35.tif or /content/OpenEarthMap/label/train/tulsa_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_42.tif or /content/OpenEarthMap/label/train/tulsa_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_43.tif or /content/OpenEarthMap/label/train/tulsa_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_45.tif or /content/OpenEarthMap/label/train/tulsa_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_48.tif or /content/OpenEarthMap/label/train/tulsa_48.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_6.tif or /content/OpenEarthMap/label/train/tulsa_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_7.tif or /content/OpenEarthMap/label/train/tulsa_7.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_8.tif or /content/OpenEarthMap/label/train/tulsa_8.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tulsa_9.tif or /content/OpenEarthMap/label/train/tulsa_9.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_1.tif or /content/OpenEarthMap/label/train/tuscaloosa_1.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_10.tif or /content/OpenEarthMap/label/train/tuscaloosa_10.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_11.tif or /content/OpenEarthMap/label/train/tuscaloosa_11.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_12.tif or /content/OpenEarthMap/label/train/tuscaloosa_12.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_13.tif or /content/OpenEarthMap/label/train/tuscaloosa_13.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_16.tif or /content/OpenEarthMap/label/train/tuscaloosa_16.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_19.tif or /content/OpenEarthMap/label/train/tuscaloosa_19.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_2.tif or /content/OpenEarthMap/label/train/tuscaloosa_2.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_22.tif or /content/OpenEarthMap/label/train/tuscaloosa_22.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_25.tif or /content/OpenEarthMap/label/train/tuscaloosa_25.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_26.tif or /content/OpenEarthMap/label/train/tuscaloosa_26.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_27.tif or /content/OpenEarthMap/label/train/tuscaloosa_27.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_28.tif or /content/OpenEarthMap/label/train/tuscaloosa_28.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_29.tif or /content/OpenEarthMap/label/train/tuscaloosa_29.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_31.tif or /content/OpenEarthMap/label/train/tuscaloosa_31.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_32.tif or /content/OpenEarthMap/label/train/tuscaloosa_32.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_34.tif or /content/OpenEarthMap/label/train/tuscaloosa_34.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_35.tif or /content/OpenEarthMap/label/train/tuscaloosa_35.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_36.tif or /content/OpenEarthMap/label/train/tuscaloosa_36.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_37.tif or /content/OpenEarthMap/label/train/tuscaloosa_37.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_39.tif or /content/OpenEarthMap/label/train/tuscaloosa_39.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_40.tif or /content/OpenEarthMap/label/train/tuscaloosa_40.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_41.tif or /content/OpenEarthMap/label/train/tuscaloosa_41.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_42.tif or /content/OpenEarthMap/label/train/tuscaloosa_42.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_43.tif or /content/OpenEarthMap/label/train/tuscaloosa_43.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_44.tif or /content/OpenEarthMap/label/train/tuscaloosa_44.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_45.tif or /content/OpenEarthMap/label/train/tuscaloosa_45.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_6.tif or /content/OpenEarthMap/label/train/tuscaloosa_6.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_7.tif or /content/OpenEarthMap/label/train/tuscaloosa_7.tif
# Warning: Missing file /content/OpenEarthMap/images/train/tuscaloosa_8.tif or /content/OpenEarthMap/label/train/tuscaloosa_8.tif
# Processing train set:  94%|█████████▍| 2813/3000 [01:21<00:10, 17.44it/s]
